# %% [markdown]
# <a href="https://colab.research.google.com/github/Motilipz/PW_Skills/blob/main/Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Neural Network - A Simple Perceptron | Assignment

# %% [markdown]
# **Question 1:** What is Deep Learning? Briefly describe how it evolved and how it differs
# from traditional machine learning.

# %% [markdown]
# Deep Learning is a subset of Machine Learning that uses multi-layer neural networks to learn hierarchical representations of data.
#
# It evolved from perceptrons to deep neural networks enabled by big data, GPUs, and better algorithms.
#
# **Difference from Traditional ML:**
# - Automatic feature extraction
# - Requires large datasets
# - Higher performance on images/text![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question 2:** Explain the basic architecture and functioning of a Perceptron. What are its
# limitations?

# %% [markdown]
# A perceptron consists of inputs, weights, bias, and an activation function.
#
# **Limitations:**
# - Only linearly separable problems
# - Cannot solve XOR
# - No hidden layers![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question 3:** Describe the purpose of activation function in neural networks. Compare
# Sigmoid, ReLU, and Tanh functions.

# %% [markdown]
# **Purpose**
#
# Activation functions:
# - Introduce non-linearity
# - Enable learning of complex patterns
# - Decide neuron output
#
# **Comparison**
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question 4:** What is the difference between Loss function and Cost function in neural
# networks? Provide examples.

# %% [markdown]
# - Loss Function: Error for one training example
# - Cost Function: Average loss over entire dataset
#
# **Examples**
# - Loss:
#   - Mean Squared Error (MSE)
#   - Binary Cross-Entropy
# - Cost:
#   - Average MSE over all samples

# %% [markdown]
# **Question 5:** What is the role of optimizers in neural networks? Compare Gradient
# Descent, Adam, and RMSprop.

# %% [markdown]
# Optimizers update weights to minimize loss.
#
# - Gradient Descent
# - RMSprop
# - Adam
#
# | Optimizer | Description | Pros | Cons |
# |---------|----------------|------|-----|
# |Gradient Descent |Uses full dataset|Stable|Slow
# |RMSprop|Adaptive learning rate|Handles non-stationary loss|Needs tuning|
# |Adam|Momentum + RMSprop|Fast, popular|Slightly more memory|

# %% [markdown]
# **Question 6:** Write a Python program to implement a single-layer perceptron from scratch using NumPy to solve the logical AND gate.

# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')

X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([0,0,0,1])

weights = np.random.rand(2)
bias = 0.0
lr = 0.1

def step(x):
    return 1 if x >= 0 else 0

for epoch in range(10):
    for i in range(len(X)):
        y_pred = step(np.dot(X[i], weights) + bias)
        error = y[i] - y_pred
        weights += lr * error * X[i]
        bias += lr * error

print("Weights:", weights)
print("Bias:", bias)
# Out:
# Weights: [0.23483689 0.42130481]
# Bias: -0.6

# %% [markdown]
# **Question 7:** Implement and visualize Sigmoid, ReLU, and Tanh activation functions using Matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10,10,100)
plt.plot(x, 1/(1+np.exp(-x)), label='Sigmoid')
plt.plot(x, np.maximum(0,x), label='ReLU')
plt.plot(x, np.tanh(x), label='Tanh')
plt.legend()
plt.show()

# %% [markdown]
# **Question 8:** Use Keras to build and train a simple multilayer neural network on the MNIST digits dataset. Print the training accuracy.

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train, X_test = X_train/255.0, X_test/255.0
y_train, y_test = to_categorical(y_train), to_categorical(y_test)

model = Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=5, validation_split=0.1)
print("Training Accuracy:", history.history['accuracy'][-1])
# Out:
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8716 - loss: 0.4526 - val_accuracy: 0.9657 - val_loss: 0.1308
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9623 - loss: 0.1279 - val_accuracy: 0.9718 - val_loss: 0.1008
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9731 - loss: 0.0872 - val_accuracy: 0.9742 - val_loss: 0.0867
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9818 - loss: 0.0596 - val_accuracy: 0.9768 - val_loss: 0.0768
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9881 - loss: 0.0440 - val_accuracy: 0.9800 - val_loss: 0.0714
# Training Accuracy: 0.985870361328125

# %% [markdown]
#  **Question 9:** Visualize the loss and accuracy curves for a neural network model trained on the Fashion MNIST dataset. Interpret the training behavior.

# %%
from tensorflow.keras.datasets import fashion_mnist

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
X_train, X_test = X_train/255.0, X_test/255.0

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

model.fit(X_train, y_train, epochs=10, validation_split=0.2)

plt.plot(model.history.history['loss'], label='Train Loss')
plt.plot(model.history.history['val_loss'], label='Val Loss')
plt.legend()
plt.show()

plt.plot(model.history.history['accuracy'], label='Train Accuracy')
plt.plot(model.history.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.7657 - loss: 0.8700 - val_accuracy: 0.8478 - val_loss: 0.4241
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8611 - loss: 0.3910 - val_accuracy: 0.8687 - val_loss: 0.3692
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8764 - loss: 0.3413 - val_accuracy: 0.8695 - val_loss: 0.3623
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8866 - loss: 0.3131 - val_accuracy: 0.8778 - val_loss: 0.3436
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8884 - loss: 0.3009 - val_accuracy: 0.8807 - val_loss: 0.3389
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8954 - loss: 0.2871 - val_accuracy: 0.8805 - val_loss: 0.3374
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9008 - loss: 0.2693 - val_accuracy: 0.8800 - val_loss: 0.3320
# Epoch 8/10
# ...

# %% [markdown]
# **Interpretation**
#
# - Increasing training accuracy → model learning
#
# - Validation loss increasing → overfitting
#
# - Close curves → good generalization

# %% [markdown]
# **Question 10:** You are working on a project for a bank that wants to automatically detect fraudulent transactions. The dataset is large, imbalanced, and contains structured features like transaction amount, merchant ID, and customer location. The goal is to classify each transaction as fraudulent or legitimate.
# **Explain your real-time data science workflow:**
# - How would you design a deep learning model (perceptron or multilayer NN)?
# - Which activation function and loss function would you use, and why?
# - How would you train and evaluate the model, considering class imbalance?
# - Which optimizer would be suitable, and how would you prevent overfitting?

# %% [markdown]
# **Model Design**
# - Use a Multilayer Neural Network
# - Input layer → structured features
# - Hidden layers → ReLU
# - Output layer → Sigmoid (binary classification)
#
# **Activation & Loss**
#
# - Activation: ReLU (hidden), Sigmoid (output)
# - Loss: Binary Cross-Entropy → suitable for probabilistic binary classification
#
# **Training & Evaluation**
#
# - Handle imbalance using:
#
#   - Class weights
#   - SMOTE
#   - Precision, Recall, F1-score (not accuracy alone)
# - Use ROC-AUC and confusion matrix
#
# **Optimizer & Overfitting Prevention**
#
# - Optimizer: Adam (fast convergence)
# - Prevent Overfitting:
#   - Dropout
#   - Early stopping
#   - L2 regularization
#   - Cross-validation
#
# **Real-Time Deployment**
#
# - Batch + streaming pipeline
# - Model monitoring & retraining
# - Threshold tuning for fraud sensitivity
